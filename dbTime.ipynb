# %% [markdown]
# # Database Report

# %% [markdown]
# ## Imports

# %%
from facebook_graph import write_post, send_picture, send_video

# %% [markdown]
# ## Posting

# %%
with open('db_reports/top_100.txt', 'r', encoding='utf-8') as txt:
    db_stats = txt.read()
    send_picture('images/image.png', db_stats)
# Out:
# 2026-08-23 23:38:50.781 | SUCCESS  | facebook_graph:send_picture:133 - Successfully posted: 122121648716847307
